# %% [markdown]
# <a href="https://colab.research.google.com/github/tinsaeabreham45/bird-detection-and-tracking/blob/main/bird_only_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun May 11 11:18:03 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/data.zip /content

# %%
# !unzip -q /content/data.zip -d /content/custom_data

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !yolo detect train data=/content/custom_data/data.yaml model=yolo11s.pt epochs=40 imgsz=640
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict model=runs/detect/train2/weights/best.pt source=custom_data/valid/images save=True
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 100 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/2045 /content/custom_data/valid/images/-E3-83-80-E3-82-A6-E3-83-B3-E3-83-AD-E3-83-BC-E3-83-89-20-10-_jpeg.rf.8c1a590fc916ba69af48886757dac4a5.jpg: 640x640 2 Birds, 15.7ms
# image 2/2045 /content/custom_data/valid/images/-E3-83-80-E3-82-A6-E3-83-B3-E3-83-AD-E3-83-BC-E3-83-89-20-28-_jpeg.rf.f30704dd5553ab1c07d6a980b8180793.jpg: 640x640 1 Bird, 15.6ms
# image 3/2045 /content/custom_data/valid/images/-E3-83-80-E3-82-A6-E3-83-B3-E3-83-AD-E3-83-BC-E3-83-89-20-8-_jpeg.rf.363c978d55876f9d43445f3a8fbe59b9.jpg: 640x640 2 Birds, 15.6ms
# image 4/2045 /content/custom_data/valid/images/000025_jpg.rf.f2bf62c1ca72facff73dd8324c96a871.jpg: 640x640 1 Bird, 15.5ms
# image 5/2045 /content/custom_data/valid/images/000042_jpg.rf.ac14cc6bbfbe31ee40ff046d4a05f7be.jpg: 640x640 1 Bird, 15.5ms
# ...

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict2/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir /content/my_model
# !cp /content/runs/detect/train2/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train2 /content/my_model
# Out:
# /content/my_model
#   adding: my_model.pt (deflated 8%)
# 	zip warning: name not matched: train
#
# zip error: Nothing to do! (try: zip -r /content/my_model.zip . -i train)
# /content

# %%
# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train2
# %cd /content
# Out:
# /content/my_model
#   adding: my_model.pt (deflated 8%)
#   adding: train2/ (stored 0%)
#   adding: train2/train_batch0.jpg (deflated 6%)
#   adding: train2/weights/ (stored 0%)
#   adding: train2/weights/best.pt (deflated 8%)
#   adding: train2/weights/last.pt (deflated 8%)
#   adding: train2/val_batch0_pred.jpg (deflated 11%)
#   adding: train2/confusion_matrix.png (deflated 37%)
#   adding: train2/R_curve.png (deflated 17%)
#   adding: train2/results.png (deflated 8%)
#   adding: train2/val_batch0_labels.jpg (deflated 12%)
#   adding: train2/results.csv (deflated 60%)
#   adding: train2/train_batch1.jpg (deflated 4%)
#   adding: train2/val_batch2_pred.jpg (deflated 7%)
#   adding: train2/labels.jpg (deflated 29%)
#   adding: train2/args.yaml (deflated 53%)
#   adding: train2/train_batch2.jpg (deflated 4%)
#   adding: train2/PR_curve.png (deflated 18%)
#   adding: train2/labels_correlogram.jpg (deflated 26%)
#   adding: train2/train_batch12512.jpg (deflated 10%)
# ...
